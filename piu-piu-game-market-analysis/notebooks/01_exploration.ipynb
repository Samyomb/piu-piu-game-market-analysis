# %% [markdown]
# # 01 – Exploration
# Placez un fichier `games.csv` dans `data/raw/` avec les colonnes minimales : `genre, platform, region, price, players, mode`.

# %%
import pandas as pd
from src.compute_metrics import avg_price_by, mix_share
from src.config import DATA_RAW
csv = DATA_RAW / 'games.csv'
df = pd.read_csv(csv)
df.head()

# %%
avg_price_by(df, ['genre'], 'price')

# %%
mix_share(df, 'mode')
